# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Machine Learning projects\Stocks Predicter\US Stock Market Dataset.csv")

# %%
df.shape
# Out:
# (1013, 39)

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0           0    2/2/2024              2.079               NaN
# 1           1    1/2/2024              2.050          161340.0
# 2           2  31-01-2024              2.100          142860.0
# 3           3  30-01-2024              2.077          139750.0
# 4           4  29-01-2024              2.490            3590.0
# 5           5  26-01-2024              2.712           73020.0
# 6           6  25-01-2024              2.571           44980.0
# 7           7  24-01-2024              2.641           65500.0
# 8           8  23-01-2024              2.450           69160.0
# 9           9  22-01-2024              2.419          121580.0
#
#    Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  \
# 0            72.28             NaN        3.8215          NaN     43,194.70
# 1            73.82        577940.0        3.8535          NaN     43,081.40
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Date                   0
# Natural_Gas_Price      0
# Natural_Gas_Vol.       4
# Crude_oil_Price        0
# Crude_oil_Vol.        23
# Copper_Price           0
# Copper_Vol.           37
# Bitcoin_Price          0
# Bitcoin_Vol.           0
# Platinum_Price         0
# Platinum_Vol.        377
# Ethereum_Price         0
# Ethereum_Vol.          0
# S&P_500_Price          0
# Nasdaq_100_Price       0
# Nasdaq_100_Vol.        1
# Apple_Price            0
# Apple_Vol.             0
# Tesla_Price            0
# Tesla_Vol.             0
# Microsoft_Price        0
# Microsoft_Vol.         0
# Silver_Price           0
# Silver_Vol.           46
# Google_Price           0
# Google_Vol.            0
# Nvidia_Price           0
# Nvidia_Vol.            0
# Berkshire_Price        0
# Berkshire_Vol.         0
# Netflix_Price          0
# Netflix_Vol.           0
# Amazon_Price           0
# Amazon_Vol.            0
# Meta_Price             0
# Meta_Vol.              0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Date                 0
# Natural_Gas_Price    0
# Natural_Gas_Vol.     0
# Crude_oil_Price      0
# Crude_oil_Vol.       0
# Copper_Price         0
# Copper_Vol.          0
# Bitcoin_Price        0
# Bitcoin_Vol.         0
# Platinum_Price       0
# Platinum_Vol.        0
# Ethereum_Price       0
# Ethereum_Vol.        0
# S&P_500_Price        0
# Nasdaq_100_Price     0
# Nasdaq_100_Vol.      0
# Apple_Price          0
# Apple_Vol.           0
# Tesla_Price          0
# Tesla_Vol.           0
# Microsoft_Price      0
# Microsoft_Vol.       0
# Silver_Price         0
# Silver_Vol.          0
# Google_Price         0
# Google_Vol.          0
# Nvidia_Price         0
# Nvidia_Vol.          0
# Berkshire_Price      0
# Berkshire_Vol.       0
# Netflix_Price        0
# Netflix_Vol.         0
# Amazon_Price         0
# Amazon_Vol.          0
# Meta_Price           0
# Meta_Vol.            0
# Gold_Price           0
# Gold_Vol.            0
# dtype: int64

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
object_cols = df.select_dtypes(include=['object']).columns
print(object_cols)
# Out:
# Index([], dtype='object')

# %%
df['Bitcoin_Price'] = df['Bitcoin_Price'].str.replace(',', '').astype(float)

# %%
df['Platinum_Price'] = df['Platinum_Price'].str.replace(',', '').astype(float)

# %%
df['Ethereum_Price'] = df['Ethereum_Price'].str.replace(',', '').astype(float)

# %%
df['Nasdaq_100_Price'] = df['Nasdaq_100_Price'].str.replace(',', '').astype(float)

# %%
df['Gold_Price'] = df['Gold_Price'].str.replace(',', '').astype(float)

# %%
df['Berkshire_Price'] = df['Berkshire_Price'].str.replace(',', '').astype(float)

# %%
df
# Out:
#      Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  Crude_oil_Vol.  \
# 28               2.572           84550.0            73.89        251980.0
# 29               2.447          125260.0            74.22        273360.0
# 30               2.492          170440.0            73.44         25690.0
# 31               2.503          154300.0            72.47         73940.0
# 32               2.491          189240.0            71.43         95510.0
# ..                 ...               ...              ...             ...
# 863              2.238          206250.0            41.22        399000.0
# 864              2.165          161990.0            41.95        359610.0
# 865              2.191          182430.0            42.19        491270.0
# 866              2.193          230890.0            41.70        451580.0
# 867              2.101          381970.0            41.01        338330.0
#
#      Copper_Price  Copper_Vol.  Bitcoin_Price  Bitcoin_Vol.  Platinum_Price  \
# ...

# %%
df.drop("Date",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.drop("Date",axis=1,inplace=True)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df
# Out:
#      Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  Crude_oil_Vol.  \
# 28               2.572           84550.0            73.89        251980.0
# 29               2.447          125260.0            74.22        273360.0
# 30               2.492          170440.0            73.44         25690.0
# 31               2.503          154300.0            72.47         73940.0
# 32               2.491          189240.0            71.43         95510.0
# ..                 ...               ...              ...             ...
# 863              2.238          206250.0            41.22        399000.0
# 864              2.165          161990.0            41.95        359610.0
# 865              2.191          182430.0            42.19        491270.0
# 866              2.193          230890.0            41.70        451580.0
# 867              2.101          381970.0            41.01        338330.0
#
#      Copper_Price  Copper_Vol.  Bitcoin_Price  Bitcoin_Vol.  Platinum_Price  \
# ...

# %%
df.drop(["S&P_500_Price"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (609, 36)

# %%
y = df.drop(["Natural_Gas_Vol.","Crude_oil_Vol.","Copper_Vol.","Bitcoin_Vol.","Platinum_Vol.","Ethereum_Vol.","Nasdaq_100_Vol.","Apple_Vol.","Tesla_Vol.","Microsoft_Vol.","Silver_Vol.","Google_Vol.","Nvidia_Vol.","Berkshire_Vol.","Netflix_Vol.","Amazon_Vol.","Meta_Vol.","Gold_Vol."],axis=1)
X = df.drop(y,axis=1)

# %%
X = X.reset_index(drop=True)

# %%
y
# Out:
#      Natural_Gas_Price  Crude_oil_Price  Copper_Price  Bitcoin_Price  \
# 28               2.572            73.89        3.9175        43865.9
# 29               2.447            74.22        3.9060        43662.8
# 30               2.492            73.44        3.8980        42259.3
# 31               2.503            72.47        3.8520        42659.7
# 32               2.491            71.43        3.8905        41929.0
# ..                 ...              ...           ...            ...
# 863              2.238            41.22        2.8020        11592.0
# 864              2.165            41.95        2.9190        11757.1
# 865              2.191            42.19        2.9250        11735.1
# 866              2.193            41.70        2.9030        11184.7
# 867              2.101            41.01        2.9205        11224.4
#
#      Platinum_Price  Ethereum_Price  Nasdaq_100_Price  Apple_Price  \
# 28            970.3         2239.62          16757.41       194.68
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(X_train)

# Transform the data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train
# Out:
#      Natural_Gas_Vol.  Crude_oil_Vol.  Copper_Vol.  Bitcoin_Vol.  \
# 155          106970.0        305340.0       1940.0        150180
# 247          192860.0        497750.0        320.0         76600
# 543          186660.0        411030.0        130.0        186130
# 577          146580.0         73760.0        160.0         63480
# 153          127670.0        379860.0       2670.0        115810
# ..                ...             ...          ...           ...
# 71           189060.0        259520.0      87260.0         51290
# 106           87550.0         59630.0       5870.0        423430
# 270           99070.0        317630.0      38420.0         41060
# 435           41280.0        361540.0       1780.0         84080
# 102          123600.0        334270.0      11230.0        431150
#
#      Platinum_Vol.  Ethereum_Vol.  Nasdaq_100_Vol.  Apple_Vol.  Tesla_Vol.  \
# 155        23960.0        1890000      223730000.0    71050000    74460000
# ...

# %%
y_train
# Out:
#      Natural_Gas_Price  Crude_oil_Price  Copper_Price  Bitcoin_Price  \
# 397              5.730           108.43        3.6200        19262.9
# 494              4.232            91.32        4.4675        43833.9
# 800              2.888            37.14        3.1570        15577.9
# 835              2.048            41.11        3.1140        10933.0
# 395              6.297           102.73        3.5770        21637.8
# ..                 ...              ...           ...            ...
# 207              2.011            80.70        4.0155        28036.7
# 345              7.752            85.73        3.5045        19538.9
# 517              3.815            76.08        4.4215        46430.2
# 687              2.873            62.94        4.4870        55036.5
# 341              6.992            78.74        3.3370        19293.5
#
#      Platinum_Price  Ethereum_Price  Nasdaq_100_Price  Apple_Price  \
# 397           871.3         1058.94          11585.68       138.93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 609 entries, 28 to 867
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Natural_Gas_Price  609 non-null    float64
#  1   Natural_Gas_Vol.   609 non-null    float64
#  2   Crude_oil_Price    609 non-null    float64
#  3   Crude_oil_Vol.     609 non-null    float64
#  4   Copper_Price       609 non-null    float64
#  5   Copper_Vol.        609 non-null    float64
#  6   Bitcoin_Price      609 non-null    float64
#  7   Bitcoin_Vol.       609 non-null    int64
#  8   Platinum_Price     609 non-null    float64
#  9   Platinum_Vol.      609 non-null    float64
#  10  Ethereum_Price     609 non-null    float64
#  11  Ethereum_Vol.      609 non-null    int64
#  12  Nasdaq_100_Price   609 non-null    float64
#  13  Nasdaq_100_Vol.    609 non-null    float64
#  14  Apple_Price        609 non-null    float64
#  15  Apple_Vol.         609 non-null    int64
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
X_train
# Out:
#      Natural_Gas_Vol.  Crude_oil_Vol.  Copper_Vol.  Bitcoin_Vol.  \
# 155          106970.0        305340.0       1940.0        150180
# 247          192860.0        497750.0        320.0         76600
# 543          186660.0        411030.0        130.0        186130
# 577          146580.0         73760.0        160.0         63480
# 153          127670.0        379860.0       2670.0        115810
# ..                ...             ...          ...           ...
# 71           189060.0        259520.0      87260.0         51290
# 106           87550.0         59630.0       5870.0        423430
# 270           99070.0        317630.0      38420.0         41060
# 435           41280.0        361540.0       1780.0         84080
# 102          123600.0        334270.0      11230.0        431150
#
#      Platinum_Vol.  Ethereum_Vol.  Nasdaq_100_Vol.  Apple_Vol.  Tesla_Vol.  \
# 155        23960.0        1890000      223730000.0    71050000    74460000
# ...

# %%
from sklearn.metrics import r2_score

y_pred = rf.predict(X_test)

r2_score(y_test,y_pred)
# Out:
# 0.8342509797460786

# %%
from sklearn.metrics import r2_score

y_pred = rf.predict([[106970.0, 305340.0, 1940.0, 150180, 23960.0, 1890000, 223730000.0, 
                        71050000, 74460000, 22840000, 75670.0, 35480000, 57760000, 1720, 
                        5200000, 73020000, 31420000, 249490.0]])


np.set_printoptions(precision=2, suppress=True)

print(y_pred)
# Out:
# [[     5.82    103.2       3.67  21853.12    893.38   1224.3   11893.12
#      140.09    231.06    260.09     20.21    110.76    151.92 415609.81
#      214.65    115.75    176.52   1788.38]]
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
y_train
# Out:
#      Natural_Gas_Price  Crude_oil_Price  Copper_Price  Bitcoin_Price  \
# 397              5.730           108.43        3.6200        19262.9
# 494              4.232            91.32        4.4675        43833.9
# 800              2.888            37.14        3.1570        15577.9
# 835              2.048            41.11        3.1140        10933.0
# 395              6.297           102.73        3.5770        21637.8
# ..                 ...              ...           ...            ...
# 207              2.011            80.70        4.0155        28036.7
# 345              7.752            85.73        3.5045        19538.9
# 517              3.815            76.08        4.4215        46430.2
# 687              2.873            62.94        4.4870        55036.5
# 341              6.992            78.74        3.3370        19293.5
#
#      Platinum_Price  Ethereum_Price  Nasdaq_100_Price  Apple_Price  \
# 397           871.3         1058.94          11585.68       138.93
# ...

# %%
import pickle 

pickle.dump(rf,open('model.pkl','wb'))
